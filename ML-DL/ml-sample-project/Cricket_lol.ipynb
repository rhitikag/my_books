# %%
https://www.espncricinfo.com/records/highest-career-batting-average-282910
# Out:
#   Cell In[1], line 1
#     https://www.espncricinfo.com/records/highest-career-batting-average-282910
#           ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# %%
df = pd.read_csv('CricketTestData.csv')

# %%
df
# Out:
#                   Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0       DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1         AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 2        RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 3        GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# 4      H Sutcliffe (ENG)  1924-1935   54    84   9  4555   194  60.73  6558+
# ..                   ...        ...  ...   ...  ..   ...   ...    ...    ...
# 60      DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
# 61  Hon.FS Jackson (ENG)  1893-1905   20    33   4  1415  144*  48.79    NaN
# 62   TT Samaraweera (SL)  2001-2013   81   132  20  5462   231  48.76  11641
# 63       RN Harvey (AUS)  1948-1963   79   137  10  6149   205  48.41  1799+
# 64      KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
#
#        SR  100  50   0    4s  6s
# ...

# %%
df.isnull().any()
# Out:
# Player    False
# Span      False
# Mat       False
# Inns      False
# NO        False
# Runs      False
# HS        False
# Ave       False
# BF         True
# SR         True
# 100       False
# 50        False
# 0         False
# 4s        False
# 6s        False
# dtype: bool

# %%
df[df['BF'].isna()==1]
# Out:
#                   Player       Span  Mat  Inns  NO  Runs    HS    Ave   BF  \
# 7         ED Weekes (WI)  1948-1958   48    81   5  4455   207  58.61  NaN
# 13       CL Walcott (WI)  1948-1960   44    74   7  3798   220  56.68  NaN
# 53  Hon.FS Jackson (ENG)  1893-1905   20    33   4  1415  144*  48.79  NaN
# 61  Hon.FS Jackson (ENG)  1893-1905   20    33   4  1415  144*  48.79  NaN
#
#      SR  100  50  0    4s  6s
# 7   0.0   15  19  6  258+   2
# 13  0.0   15  14  1  107+  11
# 53  0.0    5   6  3   51+   0
# 61  NaN    5   6  3   51+   0

# %%
df['BF'] = df['BF'].fillna(0)

# %%
df['SR'] = df['SR'].fillna(0)

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 60    False
# 61     True
# 62     True
# 63     True
# 64     True
# Length: 65, dtype: bool

# %%
df[df['Player'].duplicated()==1]
# Out:
#                   Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 61  Hon.FS Jackson (ENG)  1893-1905   20    33   4  1415  144*  48.79      0
# 62   TT Samaraweera (SL)  2001-2013   81   132  20  5462   231  48.76  11641
# 63       RN Harvey (AUS)  1948-1963   79   137  10  6149   205  48.41  1799+
# 64      KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
#
#        SR  100  50   0    4s  6s
# 61   0.00    5   6   3   51+   0
# 62  46.92   14  30  11   633   7
# 63  43.74   21  24   7  427+   1
# 64  49.16   15  33   4  525+  23

# %%
df[df['Player'].isin(['Hon.FS Jackson (ENG)', 'TT Samaraweera (SL)', 'RN Harvey (AUS)', 'KD Walters (AUS)'])]
# Out:
#                   Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 53  Hon.FS Jackson (ENG)  1893-1905   20    33   4  1415  144*  48.79      0
# 54   TT Samaraweera (SL)  2001-2013   81   132  20  5462   231  48.76  11641
# 55       RN Harvey (AUS)  1948-1963   79   137  10  6149   205  48.41  1799+
# 56      KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 61  Hon.FS Jackson (ENG)  1893-1905   20    33   4  1415  144*  48.79      0
# 62   TT Samaraweera (SL)  2001-2013   81   132  20  5462   231  48.76  11641
# 63       RN Harvey (AUS)  1948-1963   79   137  10  6149   205  48.41  1799+
# 64      KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
#
#        SR  100  50   0    4s  6s
# 53   0.00    5   6   3   51+   0
# 54  46.92   14  30  11   633   7
# 55  43.74   21  24   7  427+   1
# 56  49.16   15  33   4  525+  23
# 61   0.00    5   6   3   51+   0
# 62  46.92   14  30  11   633   7
# 63  43.74   21  24   7  427+   1
# ...

# %%
df = df.drop_duplicates()

# %%
df[df['Player'].isin(['Hon.FS Jackson (ENG)', 'TT Samaraweera (SL)', 'RN Harvey (AUS)', 'KD Walters (AUS)'])]
# Out:
#                   Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 53  Hon.FS Jackson (ENG)  1893-1905   20    33   4  1415  144*  48.79      0
# 54   TT Samaraweera (SL)  2001-2013   81   132  20  5462   231  48.76  11641
# 55       RN Harvey (AUS)  1948-1963   79   137  10  6149   205  48.41  1799+
# 56      KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
#
#        SR  100  50   0    4s  6s
# 53   0.00    5   6   3   51+   0
# 54  46.92   14  30  11   633   7
# 55  43.74   21  24   7  427+   1
# 56  49.16   15  33   4  525+  23

# %%
df['Span'].str.split(pat = '-')
# Out:
# 0     [1928, 1948]
# 1     [2015, 2016]
# 2     [1963, 1970]
# 3     [1930, 1954]
# 4     [1924, 1935]
#           ...
# 56    [1965, 1981]
# 57    [2002, 2014]
# 58    [1924, 1934]
# 59    [1930, 1938]
# 60    [1928, 1934]
# Name: Span, Length: 61, dtype: object

# %%
df['Span'].str.split(pat = '-').str[0]
# Out:
# 0     1928
# 1     2015
# 2     1963
# 3     1930
# 4     1924
#       ...
# 56    1965
# 57    2002
# 58    1924
# 59    1930
# 60    1928
# Name: Span, Length: 61, dtype: object

# %%
df['Roo']
